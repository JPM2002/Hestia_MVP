# %%
import os
import pandas as pd
import numpy as np

# 📁 Directory containing your CSVs
csv_dir = "NittanyBusinessDataset"

# 🔍 List all CSV files in the directory
csv_files = [f for f in os.listdir(csv_dir) if f.endswith(".csv")]

# ✅ Print options
print("Available CSV files:")
for i, file in enumerate(csv_files, 1):
    print(f"{i}. {file}")

# 📥 Ask user for selection
try:
    choice = int(input("Enter the number of the file you want to preview: "))
    selected_file = csv_files[choice - 1]
except (ValueError, IndexError):
    print("Invalid selection. Exiting.")
    exit()

# 📄 Full path to the selected CSV
csv_path = os.path.join(csv_dir, selected_file)

# ✅ Load and display
if os.path.exists(csv_path):
    df = pd.read_csv(csv_path)
    df = df.replace(r'^\s*$', np.nan, regex=True)  # Clean empty cells
    
    # 🛠️ Show all columns, rows, and full cell content
    pd.set_option('display.max_columns', None)
    pd.set_option('display.max_rows', None)
    pd.set_option('display.width', 1000)
    pd.set_option('display.max_colwidth', None)
    
    print(f"\n--- Preview of {selected_file} ---\n")
    print(df.head(20).to_string(index=False))  # 👈 full preview, no truncation
else:
    print(f"File not found: {csv_path}")
# Out:
# Available CSV files:
# 1. Address.csv
# 2. Buyers.csv
# 3. Categories.csv
# 4. Credit_Cards.csv
# 5. Helpdesk.csv
# 6. Orders.csv
# 7. Product_Listings.csv
# 8. Requests.csv
# 9. Reviews.csv
# 10. Sellers.csv
# 11. Users.csv
# 12. Zipcode_Info.csv
#
# --- Preview of Zipcode_Info.csv ---
#
#  zipcode         city state
#    14859     Lockwood    NY
#     1945   Marblehead    MA
#    95452      Kenwood    CA
#    56431       Aitkin    MN
#    58626  Dunn Center    ND
#    21054    Gambrills    MD
#    56713       Argyle    MN
#     4090        Wells    ME
#    92333     Fawnskin    CA
#    55786     Taconite    MN
#    26338       Camden    WV
#    67518       Beeler    KS
#    77701     Beaumont    TX
#    50058  Coon Rapids    IA
#    30720       Dalton    GA
#    26074 West Liberty    WV
#    17045    Liverpool    PA
#    67349       Howard    KS
#    16882     Woodward    PA
#    81424        Nucla    CO
